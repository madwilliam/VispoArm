# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = '/Users/william/Desktop/data/emg/'
files = os.listdir(path)
files
# Out:
# ['Issac bicep', '.DS_Store', 'extention.csv']

# %%
file = os.path.join(path,files[2])
data = pd.read_csv(file).to_numpy()
file
# Out:
# '/Users/william/Desktop/data/emg/extention.csv'

# %%
plt.plot(data[:2000])
