# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = '/Users/william/Desktop/data/emg/new recording/'
files = os.listdir(path)
files
# Out:
# ['extention0.csv', 'extention.csv']

# %%
file = os.path.join(path,files[0])
data = pd.read_csv(file).to_numpy()
file
# Out:
# '/Users/william/Desktop/data/emg/new recording/extention0.csv'

# %%
plt.plot(data[:2000])
